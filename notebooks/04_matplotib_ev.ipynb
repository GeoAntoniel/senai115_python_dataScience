# %%
#COMANDO SHIT+ENTER -. EXECUTA A LINHA SELECIONADA
print('primeira mensagem no jupyter')
# Out:
# primeira mensagem no jupyter

# %% [raw]
#                        0Instalação e importação biblioteca

# %%
#instalação biblioteca
# !pip install matplotlib

# %%
#importaçao
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv('./Bitcoin.csv')

# %%
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df = df.dropna(subset=['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(Currency)', 'Weighted_Price'])
df
# Out:
#           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 478      1325346600      4.39      4.39      4.39      4.39     48.000000
# 547      1325350740      4.50      4.57      4.50      4.57     37.862297
# 548      1325350800      4.58      4.58      4.58      4.58      9.000000
# 1224     1325391360      4.58      4.58      4.58      4.58      1.502000
# ...             ...       ...       ...       ...       ...           ...
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
df = pd.DataFrame()
display
# Out:
# <function IPython.core.display_functions.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, raw=False, clear=False, **kwargs)>

# %%
#importação:
import matplotlib.pyplot as plt
#Dados para o gráfico
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

#Criando um gráfico de linha
plt.plot(x, y)

# %%
eixo_x_anos = [2010, 2020, 2030, 2040]
eixo_y_vendas = [ 10000, 15000, 13000, 50000]
#Inserir o nome do gráfico
plt.title('Vendas curso') #titulo gráfico
#Inserir o nome do EIXO X
plt.xlabel('anos') #etiqueta(label) eixo x
#Inserir o nome do EIXO Y
plt.ylabel('vendas') #etiqueta (label eixo y

#plotar gráfico
plt.plot(eixo_x_anos, 
         eixo_y_vendas, 
         linestyle='dashed',
         linewidth=1,
        color='blue',
        marker='*',
        ms=40,
        mec='red',
        mfc='green')

# %% [raw]
# #Atividade gráfico preço bitcoin:
# Utilizando o  dataset disponível no Classroom, realizer a plotagem do gráfico entre as colunas de 'Timestamp' e 'Close'.
#
# Desafios/etapas:
# 1- importar a bibliotexa pandas no jupyter
# 2 - ler o arquivo . csv
# 3 -import pandas as pd
# import datetime as dt
#
# base = pd.read_csv("netflix daily top 10.csv")t
# 4- limpar as linhas que possuirem dados vazios
# 5 - transformar a coluna 'Timestamp' PARA O TIPO DATETIME
# 6- plotar o gráfico usando as colunas 'Timestamp' e 'Close'.
# 7- estilizar a o gráfico.

# %%
#para importar o arquivo csv é necessário que ele esteja na mesma pasta do arquivo notebook

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv('./Bitcoin.csv')

# %%
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
import pandas as pd
import datetime as dt

base = pd.read_csv("./Bitcoin.csv")

display(base)
# Out:
#           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980       NaN       NaN       NaN       NaN           NaN
# 2        1325318040       NaN       NaN       NaN       NaN           NaN
# 3        1325318100       NaN       NaN       NaN       NaN           NaN
# 4        1325318160       NaN       NaN       NaN       NaN           NaN
# ...             ...       ...       ...       ...       ...           ...
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
df.describe()

# %%
print(df.shape[0]) #verificar quantidade de linas totais na tebela
df.insull().sum() #verifica se tem linhas vazias e conta a quantidade

# %%
df = df.dropna(subset=['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(Currency)', 'Weighted_Price']) #subset e para selecionar coluna
df
# Out:
#                   Timestamp      Open      High       Low     Close  \
# 0       2011-12-31 07:52:00      4.39      4.39      4.39      4.39
# 478     2011-12-31 15:50:00      4.39      4.39      4.39      4.39
# 547     2011-12-31 16:59:00      4.50      4.57      4.50      4.57
# 548     2011-12-31 17:00:00      4.58      4.58      4.58      4.58
# 1224    2012-01-01 04:16:00      4.58      4.58      4.58      4.58
# ...                     ...       ...       ...       ...       ...
# 4857372 2021-03-30 23:56:00  58714.31  58714.31  58686.00  58686.00
# 4857373 2021-03-30 23:57:00  58683.97  58693.43  58683.97  58685.81
# 4857374 2021-03-30 23:58:00  58693.43  58723.84  58693.43  58723.84
# 4857375 2021-03-30 23:59:00  58742.18  58770.38  58742.18  58760.59
# 4857376 2021-03-31 00:00:00  58767.75  58778.18  58755.97  58778.18
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0            0.455581           2.000000        4.390000
# ...

# %%
df['Timestamp'].dtypes

# %%
df_alterado = df #Igualdade então o inverso é verdadeiro o que o df_alterado mudar df tbm mudar
df_alterado ['Timestamp'] = pd.to_daretime(df_alterado['Timestamp'],unit='s'
df_alterado.head()

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'],unit='s')
df
# Out:
#                   Timestamp      Open      High       Low     Close  \
# 0       2011-12-31 07:52:00      4.39      4.39      4.39      4.39
# 478     2011-12-31 15:50:00      4.39      4.39      4.39      4.39
# 547     2011-12-31 16:59:00      4.50      4.57      4.50      4.57
# 548     2011-12-31 17:00:00      4.58      4.58      4.58      4.58
# 1224    2012-01-01 04:16:00      4.58      4.58      4.58      4.58
# ...                     ...       ...       ...       ...       ...
# 4857372 2021-03-30 23:56:00  58714.31  58714.31  58686.00  58686.00
# 4857373 2021-03-30 23:57:00  58683.97  58693.43  58683.97  58685.81
# 4857374 2021-03-30 23:58:00  58693.43  58723.84  58693.43  58723.84
# 4857375 2021-03-30 23:59:00  58742.18  58770.38  58742.18  58760.59
# 4857376 2021-03-31 00:00:00  58767.75  58778.18  58755.97  58778.18
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0            0.455581           2.000000        4.390000
# ...

# %%
import matplotlib.pyplot as plt
x = df['Timestamp']
y = df['Close']
plt.plot(x, y)
plt.title('Preço do bitcoin ao longo dos anos')
plt.xlabel('Anos')
plt.ylabel('Preço $')
#6 - plotar o gráfico usando sa colunas 'Timestamp' e 'Close'

# %%
plt.plot(df['Timestamp'], df['Open'])
plt.plot(df['Timestamp'], df['Close'])

plt.title('Gráfico')
plt.xlabel('Data')
plt.ylabel('Ano')
plt.plot(df.close)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 plt.plot(df['Timestamp'], df['Open'])
#       2 plt.plot(df['Timestamp'], df['Close'])
#       4 plt.title('Gráfico')
#
# TypeError: list indices must be integers or slices, not str
